# %%
# !pip install tensorflow matplotlib opencv-python mediapipe scikit-learn
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.15.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.8.2-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting mediapipe
#   Using cached mediapipe-0.10.9-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting tensorflow-intel==2.15.0 (from tensorflow)
#   Using cached tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached h5py-3.10.0-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached ml_dtypes-0.2.0-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in d:\fyp\gesture decode system\action\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached protobuf-4.25.2-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in d:\fyp\gesture decode system\action\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\fyp\gesture decode system\action\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached wrapt-1.14.1-cp310-cp310-win_amd64.whl (35 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached grpcio-1.60.1-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.48.1-cp310-cp310-win_amd64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.2.0-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\fyp\gesture decode system\action\lib\site-packages (from matplotlib) (2.8.2)
# Collecting attrs>=19.1.0 (from mediapipe)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow)
#   Using cached protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.12.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Using cached threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Using cached cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow)
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached tensorflow-2.15.0-cp310-cp310-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl (300.9 MB)
# Using cached matplotlib-3.8.2-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached mediapipe-0.10.9-cp310-cp310-win_amd64.whl (50.5 MB)
# Using cached scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl (10.6 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.48.1-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached scipy-1.12.0-cp310-cp310-win_amd64.whl (46.2 MB)
# Using cached threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Using cached opencv_contrib_python-4.9.0.80-cp37-abi3-win_amd64.whl (45.3 MB)
# Using cached cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
# Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Using cached grpcio-1.60.1-cp310-cp310-win_amd64.whl (3.7 MB)
# Using cached h5py-3.10.0-cp310-cp310-win_amd64.whl (2.7 MB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# Using cached ml_dtypes-0.2.0-cp310-cp310-win_amd64.whl (938 kB)
# Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Using cached google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
# Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Using cached urllib3-2.2.0-py3-none-any.whl (120 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, urllib3, typing-extensions, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyparsing, pycparser, pyasn1, protobuf, pillow, oauthlib, numpy, MarkupSafe, markdown, kiwisolver, keras, joblib, idna, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, cachetools, attrs, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, opt-einsum, opencv-python, opencv-contrib-python, ml-dtypes, h5py, contourpy, CFFI, astunparse, sounddevice, scikit-learn, requests-oauthlib, matplotlib, google-auth, mediapipe, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed CFFI-1.16.0 MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 attrs-23.2.0 cachetools-5.3.2 certifi-2024.2.2 charset-normalizer-3.3.2 contourpy-1.2.0 cycler-0.12.1 flatbuffers-23.5.26 fonttools-4.48.1 gast-0.5.4 google-auth-2.27.0 google-auth-oauthlib-1.2.0 google-pasta-0.2.0 grpcio-1.60.1 h5py-3.10.0 idna-3.6 joblib-1.3.2 keras-2.15.0 kiwisolver-1.4.5 libclang-16.0.6 markdown-3.5.2 matplotlib-3.8.2 mediapipe-0.10.9 ml-dtypes-0.2.0 numpy-1.26.4 oauthlib-3.2.2 opencv-contrib-python-4.9.0.80 opencv-python-4.9.0.80 opt-einsum-3.3.0 pillow-10.2.0 protobuf-3.20.3 pyasn1-0.5.1 pyasn1-modules-0.3.0 pycparser-2.21 pyparsing-3.1.1 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 scikit-learn-1.4.0 scipy-1.12.0 sounddevice-0.4.6 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0 threadpoolctl-3.3.0 typing-extensions-4.9.0 urllib3-2.2.0 werkzeug-3.0.1 wheel-0.42.0 wrapt-1.14.1

# %%
import cv2
import os 
import time
from matplotlib import pyplot as plt 
import mediapipe as mp

# %%
mp_holistic =mp.solutions.holistic
mp_drawing=mp.solutions.drawing_utils

# %%
def draw_landmark(image,results):
    mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_CONTOURS,
                              mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1),)
    mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS)

# %%
def mediapipe_detection(image,model):
 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 image.flags.writeable =False
 results = model.process(image)
 image.flags.writeable=True
 image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
 return image ,results;

# %%
cap = cv2.VideoCapture(0)


with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
 while cap.isOpened():
    ret ,frame = cap.read()
    image,results=mediapipe_detection(frame ,holistic)
    
    draw_landmark(image,results)
    cv2.imshow("Real time feed" , image)
    if cv2.waitKey(10) & 0xFF==ord("q"):
       break
 cap.release()
 cv2.destroyAllWindows()

# %%
draw_landmark(frame , results)

# %%
plt.imshow(cv2.cvtColor(frame , cv2.COLOR_BGR2RGB))

# %%
results.left_hand_landmarks
# Out:
# landmark {
#   x: 0.7869269847869873
#   y: 0.7673940658569336
#   z: 3.395073520096048e-07
# }
# landmark {
#   x: 0.7192407846450806
#   y: 0.7360294461250305
#   z: -0.027066072449088097
# }
# landmark {
#   x: 0.6642006635665894
#   y: 0.6655000448226929
#   z: -0.04179547727108002
# }
# landmark {
#   x: 0.6250893473625183
#   y: 0.6054251194000244
#   z: -0.05461768060922623
# }
# landmark {
#   x: 0.5866686105728149
#   y: 0.5653827786445618
#   z: -0.06769203394651413
# }
# landmark {
#   x: 0.7236077189445496
#   y: 0.5427760481834412
#   z: -0.022443266585469246
# }
# landmark {
#   x: 0.7092685699462891
#   y: 0.452518492937088
#   z: -0.04350980743765831
# }
# landmark {
#   x: 0.702345073223114
#   y: 0.3969665467739105
#   z: -0.06276039034128189
# }
# landmark {
#   x: 0.6985280513763428
#   y: 0.3473860025405884
#   z: -0.07774470746517181
# }
# landmark {
#   x: 0.7685630917549133
#   y: 0.5299057960510254
#   z: -0.026850134134292603
# }
# landmark {
#   x: 0.7650365829467773
#   y: 0.4256230592727661
#   z: -0.043558649718761444
# }
# landmark {
#   x: 0.763468861579895
#   y: 0.35871273279190063
#   z: -0.0603458397090435
# }
# landmark {
#   x: 0.7630502581596375
#   y: 0.3008301556110382
#   z: -0.07384005188941956
# }
# landmark {
#   x: 0.8099336624145508
#   y: 0.5418010950088501
#   z: -0.03539099544286728
# }
# landmark {
#   x: 0.8175211548805237
#   y: 0.4432554244995117
#   z: -0.05434699356555939
# }
# landmark {
#   x: 0.820317268371582
#   y: 0.3803718090057373
#   z: -0.06720241159200668
# }
# landmark {
#   x: 0.8194211721420288
#   y: 0.32469356060028076
#   z: -0.07723955810070038
# }
# landmark {
#   x: 0.8486634492874146
#   y: 0.5732830166816711
#   z: -0.0464526005089283
# }
# landmark {
#   x: 0.8617647290229797
#   y: 0.5054056644439697
#   z: -0.06461016833782196
# }
# landmark {
#   x: 0.8632505536079407
#   y: 0.46142685413360596
#   z: -0.0707729235291481
# }
# landmark {
#   x: 0.8585255742073059
#   y: 0.42188525199890137
#   z: -0.07523752003908157
# }

# %%
# newTest=[]
# for res in results.pose_landmarks.landmark:
#     test=np.array([res.x , res.y , res.z ,res.visibility])
#     newTest.append(test);
    
# pose =np.array(newTest).flatten()
# pose

# %%
def extract_keypoints(results):
    right_hand=np.array([[res.x ,res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    left_hand=np.array([[res.x ,res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks.landmark else np.zeros(21*3)
    face=np.array([[res.x ,res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks.landmark else np.zeros(468*3)
    pose=np.array([[res.x ,res.y, res.z , res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks.landmark else np.zeros(33*4)
    return np.concatenate([pose , face , left_hand , right_hand])

# %%
len(extract_keypoints(results))
# Out:
# 1662

# %%
# path for exported data numpy array
data_Path = os.path.join("MP_DATA")

# action we want to detect 
actions =["hello" , "good bye" , "good morning"]

# number of vides or sequence of each action
no_of_sequence = 30

# number of frames per video or sequence
sequnece_length =30

# %%
for action in actions:
    for sequence in range(no_of_sequence):
        try:
          os.makedirs(os.path.join(data_Path , action , str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(no_of_sequence):
            for frame_num in range(sequnece_length):
                ret, frame = cap.read()
                image, results = mediapipe_detection(frame, holistic)
                draw_landmark(image, results)

                # NEW Apply wait logic
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    # cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else:
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow("Real time feed", image)

                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, folder, str(frame_num))
                np.save(npy_path, keypoints)

                if cv2.waitKey(10) & 0xFF == ord("q"):
                    break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 24
#      20     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
#      21                 cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#      22     cv2.imshow("Real time feed", image)
# ---> 24 keypoints = extract_keypoints(results)
#      25 npy_path = os.path.join(DATA_PATH, action, folder, str(frame_num))
#      26 np.save(npy_path, keypoints)
#
# Cell In[11], line 3, in extract_keypoints(results)
#       1 def extract_keypoints(results):
#       2     right_hand=np.array([[res.x ,res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
# ----> 3     left_hand=np.array([[res.x ,res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks.landmark else np.zeros(21*3)
#       4     face=np.array([[res.x ,res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks.landmark else np.zeros(468*3)
#       5     pose=np.array([[res.x ,res.y, res.z , res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks.landmark else np.zeros(33*4)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
cap.release()
cv2.destroyAllWindows()
